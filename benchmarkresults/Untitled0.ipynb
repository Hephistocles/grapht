# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_gtk3agg.py:18: UserWarning: The Gtk3Agg backend is known to not work on Python 3.x with pycairo. Try installing cairocffi.
#   "The Gtk3Agg backend is known to not work on Python 3.x with pycairo. "

# %%
df = pd.read_csv("prefetcher5.csv")

# %%
df
# Out:
#    Prefetcher   Size   Start     End  Vertices Requested  Vertices Evicted  \
# 0      Block       1       1      50                6573                 0
# 1      Block       1       1      50                6573                 0
# 2      Block       1       1      50                6573                 0
# 3      Block       1       1      50                6573                 0
# 4      Block       1       1      50                6573                 0
# 5      Block       1       1      50                6573                 0
# 6      Block       1       1      50                6573                 0
# 7      Block       1       1      50                6573                 0
# 8      Block       1       1      50                6573                 0
# 9      Block       1       1      50                6573                 0
# 10     Block       1  171677  164352               14091                 0
# 11     Block       1  171677  164352               14091                 0
# 12     Block      10       1      50                6573                 0
# 13     Block      10       1      50                6573                 0
# 14     Block      10       1      50                6573                 0
# 15     Block      10       1      50                6573                 0
# 16     Block      10       1      50                6573                 0
# 17     Block      10       1      50                6573                 0
# 18     Block      10       1      50                6573                 0
# 19     Block      10       1      50                6573                 0
# 20     Block      10       1      50                6573                 0
# 21     Block      10       1      50                6573                 0
# 22     Block      10  171677  164352               14091                 0
# 23     Block      10  171677  164352               14091                 0
# 24     Block     100       1      50                6573                 0
# 25     Block     100       1      50                6573                 0
# 26     Block     100       1      50                6573                 0
# 27     Block     100       1      50                6573                 0
# 28     Block     100       1      50                6573                 0
# 29     Block     100       1      50                6573                 0
# 30     Block     100       1      50                6573                 0
# 31     Block     100       1      50                6573                 0
# 32     Block     100       1      50                6573                 0
# 33     Block     100       1      50                6573                 0
# 34     Block     100  171677  164352               14091                 0
# 35     Block    1000       1      50                6573                 0
# 36     Block    1000       1      50                6573                 0
# 37     Block    1000       1      50                6573                 0
# 38     Block    1000       1      50                6573                 0
# 39     Block    1000       1      50                6573                 0
# 40     Block    1000       1      50                6573                 0
# 41     Block    1000       1      50                6573                 0
# 42     Block    1000       1      50                6573                 0
# 43     Block    1000       1      50                6573                 0
# 44     Block    1000       1      50                6573                 0
# 45     Block    1000  171677  164352               14091                 0
# 46     Block   10000       1      50                6573                 0
# 47     Block   10000       1      50                6573                 0
# 48     Block   10000       1      50                6573                 0
# 49     Block   10000       1      50                6573                 0
# 50     Block   10000       1      50                6573                 0
# 51     Block   10000       1      50                6573                 0
# 52     Block   10000       1      50                6573                 0
# 53     Block   10000       1      50                6573                 0
# 54     Block   10000       1      50                6573                 0
# 55     Block   10000       1      50                6573                 0
# 56     Block   10000  171677  164352               14091                 0
# 57     Block   20000       1      50                6573                 0
# 58     Block   20000       1      50                6573                 0
# 59     Block   20000       1      50                6573                 0
#           ...    ...     ...     ...                 ...               ...
#
#     Cache Hits   Cache Misses  Total Runtime  Total DB time  DB calls
# 0         1404           5169   280746011929   279809586397      5169
# 1         1404           5169   281677608069   280731281758      5169
# 2         1404           5169   284461228412   283540507826      5169
# 3         1404           5169   287077738457   286142759429      5169
# 4         1404           5169   288290372678   287364735287      5169
# 5         1404           5169   288955852964   288015836934      5169
# 6         1404           5169   289103340208   288194406162      5169
# 7         1404           5169   289175933431   288040214449      5169
# 8         1404           5169   292359940589   291413736591      5169
# 9         1404           5169   296147922446   295143472886      5169
# 10        5109           8982   495440621983   493593050988      8982
# 11        5109           8982   577970660056   576401129574      8982
# 12        1404           5169   287192974041   286239162875      5169
# 13        1404           5169   292525604460   291582341792      5169
# 14        1404           5169   293690372008   292718383489      5169
# 15        1404           5169   294360124606   293383955271      5169
# 16        1404           5169   294672215572   293711622407      5169
# 17        1404           5169   295914366201   294981141008      5169
# 18        1404           5169   296410551648   295486455526      5169
# 19        1404           5169   297381099100   296445749723      5169
# 20        1404           5169   298420414155   297499671618      5169
# 21        1404           5169   302192603031   301266305192      5169
# 22        5110           8981   489934806914   488213040771      8981
# 23        5110           8981   498291894461   496549895634      8981
# 24        1414           5159   280004858959   279021511678      5159
# 25        1414           5159   288910513626   287947423067      5159
# 26        1414           5159   289577599649   288669831880      5159
# 27        1414           5159   290532195287   289617484127      5159
# 28        1414           5159   290897800976   289945982188      5159
# 29        1414           5159   291713031832   290735539956      5159
# 30        1414           5159   296294774372   295342777905      5159
# 31        1414           5159   297327381588   296396795111      5159
# 32        1414           5159   297384254276   296451947338      5159
# 33        1414           5159   297388235343   296418572471      5159
# 34        5160           8931   485389212394   483751995674      8931
# 35        3443           3130   170135250462   169412587621      3130
# 36        3443           3130   170685042347   169961639094      3130
# 37        3443           3130   174893236722   174188758419      3130
# 38        3443           3130   175123961310   174436308229      3130
# 39        3443           3130   175395633702   174693517389      3130
# 40        3443           3130   175510356592   174772418767      3130
# 41        3443           3130   177049115407   176336021408      3130
# 42        3443           3130   177791244177   177099453703      3130
# 43        3443           3130   183563580453   182863669242      3130
# 44        3443           3130   185528188936   184807492192      3130
# 45       10431           3660   197182348865   196017235847      3660
# 46        6433            140    10008892939     8629969865       140
# 47        6433            140    10053153067     8649665127       140
# 48        6433            140    10123247393     8756575553       140
# 49        6433            140     9225039098     8122104880       140
# 50        6433            140     9278800747     8195270085       140
# 51        6433            140     9325864266     8108539081       140
# 52        6433            140     9421886631     8105110496       140
# 53        6433            140     9422108035     8138204126       140
# 54        6433            140     9509478924     8196679700       140
# 55        6433            140     9798528831     8505044841       140
# 56       13990            101    13567355196     8933860809       101
# 57        6531             42     5852433141     3493830301        42
# 58        6531             42     5982447320     3584536856        42
# 59        6531             42     6092228876     3401188182        42
#            ...            ...            ...            ...       ...
#
# [424 rows x 11 columns]

# %%
stats_grouped = df.groupby(['Prefetcher', 'End', 'Size'])

# %%
endpoints = [50, 164352]

# %%
prefetchers = ["Lookahead ", "CTE Lookahead ", "Block "]

# %%
    # %matplotlib inline

# %%
plt.style.available
# Out:
# ['seaborn-notebook',
#  'classic',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'fivethirtyeight',
#  'dark_background',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-muted',
#  'seaborn-dark',
#  'seaborn-bright',
#  'seaborn-deep',
#  'grayscale',
#  'seaborn-pastel',
#  'bmh',
#  'seaborn-whitegrid',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'seaborn-darkgrid',
#  'seaborn-paper']

# %%
# Out:
# '0.13.1'

# %%
for prefetcher, d in df.groupby("Prefetcher"):
    if (prefetcher == "Null Prefetcher"):
        continue
    fig = plt.figure()
    for endpoint, d in d.groupby("End"):
        vals = d.groupby("Size")["Total DB time"].mean()
        vals.plot(y
    plt.legend(loc="upper right")
    plt.suptitle(prefetcher)

# %%
vals.head(n=10)
# Out:
# Size
# 0     412    10470426427
#       413    10767229897
#       414    10967425162
#       415    11008859551
#       416    11022131627
#       417    11173501473
#       418    11774415387
#       419    12078167532
#       420    12457826104
#       421     9753339296
# Name: Total Runtime, dtype: int64
